# %%
from modulo_arvores.arvore_trie import *
from modulo_arvores.utils import *
from objects.logger import Logger

# %%
Logger.get_instance().activate()
trie = Trie()
# Out:
# 2025-03-24 12:59:03,601: Árvore Trie criada com sucesso.

# %%
trie.inserir("HELICOPTERO")
trie.inserir("HELICOPTERA")
trie.inserir("COMBATE")
trie.inserir("elefante")
# trie.inserir("galo")
# Out:
# 2025-03-24 12:59:03,685: Inserida a palavra 'HELICOPTERO'.
# 2025-03-24 12:59:03,687: Árvore atual:
# Raiz
#     H
#     └──
#         E
#         └──
#             L
#             └──
#                 I
#                 └──
#                     C
#                     └──
#                         O
#                         └──
#                             P
#                             └──
#                                 T
#                                 └──
#                                     E
#                                     └──
#                                         R
#                                         └──
#                                             O
#                                             └──  [Fim]
#
# 2025-03-24 12:59:03,688: Inserida a palavra 'HELICOPTERA'.
# 2025-03-24 12:59:03,689: Árvore atual:
# Raiz
#     H
#     └──
#         E
#         └──
#             L
#             └──
#                 I
#                 └──
# ...

# %%
trie.remover("HELICOPTERA")
# Out:
# 2025-03-24 12:59:03,776: Removida a palavra 'HELICOPTERA'.
# 2025-03-24 12:59:03,778: Árvore atual:
# Raiz
#     H
#     ├──
#     │   E
#     │   └──
#     │       L
#     │       └──
#     │           I
#     │           └──
#     │               C
#     │               └──
#     │                   O
#     │                   └──
#     │                       P
#     │                       └──
#     │                           T
#     │                           └──
#     │                               E
#     │                               └──
#     │                                   R
#     │                                   └──
#     │                                       O
#     │                                       └──  [Fim]
#     C
#     ├──
#     │   O
#     │   └──
#     │       M
#     │       └──
#     │           B
#     │           └──
#     │               A
#     │               └──
#     │                   T
#     │                   └──
# ...
