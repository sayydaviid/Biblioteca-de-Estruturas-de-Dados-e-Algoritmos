# %%
from modulo_arvores import Trie
from objects import Logger, utils

# %%
Logger.get_instance().activate()
trie = Trie()
# Out:
# 2025-03-26 16:24:33,903: Árvore Trie criada com sucesso.

# %%
trie.inserir("HELICOPTERO")
trie.inserir("HELICOPTERA")
trie.inserir("COMBATE")
trie.inserir("elefante")
# trie.inserir("galo")
# Out:
# 2025-03-26 16:24:33,908: Inserida a palavra 'HELICOPTERO'.
# 2025-03-26 16:24:33,908: Árvore atual:
# Raiz
#     H
#     └──
#         E
#         └──
#             L
#             └──
#                 I
#                 └──
#                     C
#                     └──
#                         O
#                         └──
#                             P
#                             └──
#                                 T
#                                 └──
#                                     E
#                                     └──
#                                         R
#                                         └──
#                                             O
#                                             └──  [Fim]
#
# 2025-03-26 16:24:33,909: Inserida a palavra 'HELICOPTERA'.
# 2025-03-26 16:24:33,909: Árvore atual:
# Raiz
#     H
#     └──
#         E
#         └──
#             L
#             └──
#                 I
#                 └──
#                     C
#                     └──
#                         O
#                         └──
#                             P
#                             └──
#                                 T
#                                 └──
#                                     E
#                                     └──
#                                         R
#                                         └──
#                                             O
#                                             ├──  [Fim]
#                                             A
#                                             └──  [Fim]
#
# 2025-03-26 16:24:33,910: Inserida a palavra 'COMBATE'.
# 2025-03-26 16:24:33,910: Árvore atual:
# Raiz
#     H
#     ├──
#     │   E
#     │   └──
#     │       L
#     │       └──
#     │           I
#     │           └──
#     │               C
#     │               └──
#     │                   O
#     │                   └──
#     │                       P
#     │                       └──
#     │                           T
#     │                           └──
#     │                               E
#     │                               └──
#     │                                   R
#     │                                   └──
#     │                                       O
#     │                                       ├──  [Fim]
#     │                                       A
#     │                                       └──  [Fim]
#     C
#     └──
#         O
#         └──
#             M
#             └──
#                 B
#                 └──
#                     A
#                     └──
#                         T
#                         └──
#                             E
#                             └──  [Fim]
#
# 2025-03-26 16:24:33,911: Inserida a palavra 'elefante'.
# 2025-03-26 16:24:33,911: Árvore atual:
# Raiz
#     H
#     ├──
#     │   E
#     │   └──
#     │       L
#     │       └──
#     │           I
#     │           └──
#     │               C
#     │               └──
#     │                   O
#     │                   └──
#     │                       P
#     │                       └──
#     │                           T
#     │                           └──
#     │                               E
#     │                               └──
#     │                                   R
#     │                                   └──
#     │                                       O
#     │                                       ├──  [Fim]
#     │                                       A
#     │                                       └──  [Fim]
#     C
#     ├──
#     │   O
#     │   └──
#     │       M
#     │       └──
#     │           B
#     │           └──
#     │               A
#     │               └──
#     │                   T
#     │                   └──
#     │                       E
#     │                       └──  [Fim]
#     e
#     └──
#         l
#         └──
#             e
#             └──
#                 f
#                 └──
#                     a
#                     └──
#                         n
#                         └──
#                             t
#                             └──
#                                 e
#                                 └──  [Fim]

# %%
trie.remover("HELICOPTERA")
# Out:
# 2025-03-26 16:24:33,917: Removida a palavra 'HELICOPTERA'.
# 2025-03-26 16:24:33,918: Árvore atual:
# Raiz
#     H
#     ├──
#     │   E
#     │   └──
#     │       L
#     │       └──
#     │           I
#     │           └──
#     │               C
#     │               └──
#     │                   O
#     │                   └──
#     │                       P
#     │                       └──
#     │                           T
#     │                           └──
#     │                               E
#     │                               └──
#     │                                   R
#     │                                   └──
#     │                                       O
#     │                                       └──  [Fim]
#     C
#     ├──
#     │   O
#     │   └──
#     │       M
#     │       └──
#     │           B
#     │           └──
#     │               A
#     │               └──
#     │                   T
#     │                   └──
#     │                       E
#     │                       └──  [Fim]
#     e
#     └──
#         l
#         └──
#             e
#             └──
#                 f
#                 └──
#                     a
#                     └──
#                         n
#                         └──
#                             t
#                             └──
#                                 e
#                                 └──  [Fim]
