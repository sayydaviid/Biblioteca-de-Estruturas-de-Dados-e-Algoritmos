# %%
from modulo_arvores.arvore_avl import * 
from modulo_arvores.utils import *
from objects.logger import Logger
import random

# %%
# Ativando o Logger
Logger.get_instance().activate()  # Ativando o logger
arvore = ArvoreAVL()
# Out:
# 2025-03-24 12:52:26,432: Árvore AVL criada com sucesso.

# %%
# # Gerando 3 valores aleatórios entre 1 e 100
# valores = gerar_valores(quantidade=3, aleatorio=True, limite=100)


# # Inserindo os valores na árvore e exibindo o passo a passo
# for valor in valores:
#     arvore.inserir_raiz(valor)  

# # Escolher um valor aleatório para remoção
# valor_remover = random.choice(valores)

# # Remover o valor escolhido da árvore
# arvore.remover_raiz(valor_remover)

# %%
# arvore.exibir_arvore()

# %% [markdown]
# #### INSERINDO VALORES

# %%
arvore.inserir_raiz(50)
arvore.inserir_raiz(30)
arvore.inserir_raiz(70)
arvore.inserir_raiz(80)
# Out:
# 2025-03-24 12:52:26,871: Árvore após inserção do valor 50:
# 2025-03-24 12:52:26,872: └── 50
# 2025-03-24 12:52:26,873: Árvore após inserção do valor 30:
# 2025-03-24 12:52:26,874: └── 50
# 2025-03-24 12:52:26,875:     └── 30
# 2025-03-24 12:52:26,875: Árvore após inserção do valor 70:
# 2025-03-24 12:52:26,876: └── 50
# 2025-03-24 12:52:26,877:     ├── 70
# 2025-03-24 12:52:26,877:     └── 30
# 2025-03-24 12:52:26,878: Árvore após inserção do valor 80:
# 2025-03-24 12:52:26,878: └── 50
# 2025-03-24 12:52:26,878:     ├── 70
# 2025-03-24 12:52:26,879:     │   ├── 80
# 2025-03-24 12:52:26,879:     └── 30

# %%
arvore.limpar_arvore()
# Out:
# 2025-03-24 12:52:27,031: Árvore AVL limpa com sucesso.

# %% [markdown]
# #### ROTAÇÃO A DIREITA

# %%
arvore.inserir_raiz(10)
arvore.inserir_raiz(6)
arvore.inserir_raiz(15)
arvore.inserir_raiz(17)
arvore.inserir_raiz(7)
arvore.inserir_raiz(3)
arvore.inserir_raiz(4)
arvore.inserir_raiz(2)
arvore.inserir_raiz(1)
# Out:
# 2025-03-24 12:52:27,106: Árvore após inserção do valor 10:
# 2025-03-24 12:52:27,108: └── 10
# 2025-03-24 12:52:27,108: Árvore após inserção do valor 6:
# 2025-03-24 12:52:27,109: └── 10
# 2025-03-24 12:52:27,109:     └── 6
# 2025-03-24 12:52:27,110: Árvore após inserção do valor 15:
# 2025-03-24 12:52:27,111: └── 10
# 2025-03-24 12:52:27,111:     ├── 15
# 2025-03-24 12:52:27,112:     └── 6
# 2025-03-24 12:52:27,113: Árvore após inserção do valor 17:
# 2025-03-24 12:52:27,114: └── 10
# 2025-03-24 12:52:27,115:     ├── 15
# 2025-03-24 12:52:27,115:     │   ├── 17
# 2025-03-24 12:52:27,116:     └── 6
# 2025-03-24 12:52:27,117: Árvore após inserção do valor 7:
# 2025-03-24 12:52:27,117: └── 10
# 2025-03-24 12:52:27,118:     ├── 15
# 2025-03-24 12:52:27,118:     │   ├── 17
# 2025-03-24 12:52:27,118:     └── 6
# 2025-03-24 12:52:27,119:         ├── 7
# 2025-03-24 12:52:27,119: Árvore após inserção do valor 3:
# 2025-03-24 12:52:27,120: └── 10
# 2025-03-24 12:52:27,120:     ├── 15
# ...

# %%
arvore.exibir_arvore()
# Out:
# 2025-03-24 12:52:27,187: └── 10
# 2025-03-24 12:52:27,191:     ├── 15
# 2025-03-24 12:52:27,192:     │   ├── 17
# 2025-03-24 12:52:27,193:     └── 3
# 2025-03-24 12:52:27,194:         ├── 6
# 2025-03-24 12:52:27,196:         │   ├── 7
# 2025-03-24 12:52:27,197:         │   └── 4
# 2025-03-24 12:52:27,198:         └── 2
# 2025-03-24 12:52:27,198:             └── 1

# %%
arvore.limpar_arvore()
# Out:
# 2025-03-24 12:52:27,265: Árvore AVL limpa com sucesso.

# %% [markdown]
# #### ROTAÇÃO A ESQUERDA

# %%
arvore.inserir_raiz(32)
arvore.inserir_raiz(31)
arvore.inserir_raiz(35)
arvore.inserir_raiz(33)
arvore.inserir_raiz(36)
arvore.inserir_raiz(38)
# Out:
# 2025-03-24 12:52:27,340: Árvore após inserção do valor 32:
# 2025-03-24 12:52:27,341: └── 32
# 2025-03-24 12:52:27,342: Árvore após inserção do valor 31:
# 2025-03-24 12:52:27,343: └── 32
# 2025-03-24 12:52:27,344:     └── 31
# 2025-03-24 12:52:27,346: Árvore após inserção do valor 35:
# 2025-03-24 12:52:27,346: └── 32
# 2025-03-24 12:52:27,347:     ├── 35
# 2025-03-24 12:52:27,347:     └── 31
# 2025-03-24 12:52:27,348: Árvore após inserção do valor 33:
# 2025-03-24 12:52:27,349: └── 32
# 2025-03-24 12:52:27,351:     ├── 35
# 2025-03-24 12:52:27,352:     │   └── 33
# 2025-03-24 12:52:27,353:     └── 31
# 2025-03-24 12:52:27,354: Árvore após inserção do valor 36:
# 2025-03-24 12:52:27,354: └── 32
# 2025-03-24 12:52:27,355:     ├── 35
# 2025-03-24 12:52:27,355:     │   ├── 36
# 2025-03-24 12:52:27,356:     │   └── 33
# 2025-03-24 12:52:27,356:     └── 31
# 2025-03-24 12:52:27,357: Árvore após inserção do valor 38:
# 2025-03-24 12:52:27,358: └── 32
# 2025-03-24 12:52:27,359:     ├── 35
# ...

# %%
arvore.exibir_arvore()
# Out:
# 2025-03-24 12:52:27,415: └── 35
# 2025-03-24 12:52:27,416:     ├── 36
# 2025-03-24 12:52:27,417:     │   ├── 38
# 2025-03-24 12:52:27,418:     └── 32
# 2025-03-24 12:52:27,419:         ├── 33
# 2025-03-24 12:52:27,420:         └── 31

# %%
arvore.limpar_arvore()
# Out:
# 2025-03-24 12:52:27,495: Árvore AVL limpa com sucesso.

# %% [markdown]
# #### DUPLA ROTAÇÃO A DIREITA

# %%
arvore.inserir_raiz(10)
arvore.inserir_raiz(6)
arvore.inserir_raiz(15)
arvore.inserir_raiz(17)
arvore.inserir_raiz(7)
arvore.inserir_raiz(3)
arvore.inserir_raiz(4)
arvore.inserir_raiz(2)
arvore.inserir_raiz(5)
# Out:
# 2025-03-24 12:52:27,573: Árvore após inserção do valor 10:
# 2025-03-24 12:52:27,575: └── 10
# 2025-03-24 12:52:27,577: Árvore após inserção do valor 6:
# 2025-03-24 12:52:27,578: └── 10
# 2025-03-24 12:52:27,579:     └── 6
# 2025-03-24 12:52:27,579: Árvore após inserção do valor 15:
# 2025-03-24 12:52:27,580: └── 10
# 2025-03-24 12:52:27,580:     ├── 15
# 2025-03-24 12:52:27,581:     └── 6
# 2025-03-24 12:52:27,581: Árvore após inserção do valor 17:
# 2025-03-24 12:52:27,582: └── 10
# 2025-03-24 12:52:27,582:     ├── 15
# 2025-03-24 12:52:27,583:     │   ├── 17
# 2025-03-24 12:52:27,583:     └── 6
# 2025-03-24 12:52:27,584: Árvore após inserção do valor 7:
# 2025-03-24 12:52:27,584: └── 10
# 2025-03-24 12:52:27,585:     ├── 15
# 2025-03-24 12:52:27,585:     │   ├── 17
# 2025-03-24 12:52:27,586:     └── 6
# 2025-03-24 12:52:27,586:         ├── 7
# 2025-03-24 12:52:27,587: Árvore após inserção do valor 3:
# 2025-03-24 12:52:27,587: └── 10
# 2025-03-24 12:52:27,588:     ├── 15
# ...

# %%
arvore.exibir_arvore()
# Out:
# 2025-03-24 12:52:27,706: └── 10
# 2025-03-24 12:52:27,708:     ├── 15
# 2025-03-24 12:52:27,709:     │   ├── 17
# 2025-03-24 12:52:27,710:     └── 4
# 2025-03-24 12:52:27,711:         ├── 6
# 2025-03-24 12:52:27,712:         │   ├── 7
# 2025-03-24 12:52:27,712:         │   └── 5
# 2025-03-24 12:52:27,713:         └── 3
# 2025-03-24 12:52:27,713:             └── 2

# %%
arvore.limpar_arvore()
# Out:
# 2025-03-24 12:52:27,779: Árvore AVL limpa com sucesso.

# %% [markdown]
# #### ROTAÇÃO DUPLA A ESQUERDA

# %%
arvore.inserir_raiz(10)
arvore.inserir_raiz(6)
arvore.inserir_raiz(15)
arvore.inserir_raiz(17)
arvore.inserir_raiz(7)
arvore.inserir_raiz(3)
arvore.inserir_raiz(4)
arvore.inserir_raiz(2)
arvore.inserir_raiz(16)
# Out:
# 2025-03-24 12:52:27,872: Árvore após inserção do valor 10:
# 2025-03-24 12:52:27,876: └── 10
# 2025-03-24 12:52:27,879: Árvore após inserção do valor 6:
# 2025-03-24 12:52:27,880: └── 10
# 2025-03-24 12:52:27,882:     └── 6
# 2025-03-24 12:52:27,883: Árvore após inserção do valor 15:
# 2025-03-24 12:52:27,884: └── 10
# 2025-03-24 12:52:27,885:     ├── 15
# 2025-03-24 12:52:27,886:     └── 6
# 2025-03-24 12:52:27,887: Árvore após inserção do valor 17:
# 2025-03-24 12:52:27,887: └── 10
# 2025-03-24 12:52:27,888:     ├── 15
# 2025-03-24 12:52:27,888:     │   ├── 17
# 2025-03-24 12:52:27,889:     └── 6
# 2025-03-24 12:52:27,890: Árvore após inserção do valor 7:
# 2025-03-24 12:52:27,891: └── 10
# 2025-03-24 12:52:27,897:     ├── 15
# 2025-03-24 12:52:27,898:     │   ├── 17
# 2025-03-24 12:52:27,899:     └── 6
# 2025-03-24 12:52:27,901:         ├── 7
# 2025-03-24 12:52:27,902: Árvore após inserção do valor 3:
# 2025-03-24 12:52:27,903: └── 10
# 2025-03-24 12:52:27,904:     ├── 15
# ...

# %%
arvore.exibir_arvore()
# Out:
# 2025-03-24 12:52:27,963: └── 10
# 2025-03-24 12:52:27,967:     ├── 16
# 2025-03-24 12:52:27,968:     │   ├── 17
# 2025-03-24 12:52:27,969:     │   └── 15
# 2025-03-24 12:52:27,970:     └── 6
# 2025-03-24 12:52:27,971:         ├── 7
# 2025-03-24 12:52:27,972:         └── 3
# 2025-03-24 12:52:27,973:             ├── 4
# 2025-03-24 12:52:27,974:             └── 2

# %%
arvore.limpar_arvore()
# Out:
# 2025-03-24 12:52:28,044: Árvore AVL limpa com sucesso.

# %% [markdown]
# #### REMOÇÃO

# %%
valores = [10, 20, 30, 5, 3, 50, 40, 70, 60, 90]
for valor in valores:
    arvore.inserir_raiz(valor)
    
valor_remover = random.choice(valores)
arvore.remover_raiz(valor_remover)
# Out:
# 2025-03-24 12:52:28,124: Árvore após inserção do valor 10:
# 2025-03-24 12:52:28,134: └── 10
# 2025-03-24 12:52:28,137: Árvore após inserção do valor 20:
# 2025-03-24 12:52:28,138: └── 10
# 2025-03-24 12:52:28,139:     ├── 20
# 2025-03-24 12:52:28,142: Árvore após inserção do valor 30:
# 2025-03-24 12:52:28,144: └── 10
# 2025-03-24 12:52:28,151:     ├── 20
# 2025-03-24 12:52:28,153:     │   ├── 30
# 2025-03-24 12:52:28,154: Rotação à esquerda no nó 10 devido ao fator de balanceamento < -1.
# 2025-03-24 12:52:28,156: Iniciando rotação à esquerda no nó 10.
# 2025-03-24 12:52:28,157: Rotação à esquerda no nó 10 concluída.
# 2025-03-24 12:52:28,160: Árvore após balanceamento do valor 30:
# 2025-03-24 12:52:28,162: └── 20
# 2025-03-24 12:52:28,165:     ├── 30
# 2025-03-24 12:52:28,176:     └── 10
# 2025-03-24 12:52:28,180: Árvore após inserção do valor 5:
# 2025-03-24 12:52:28,184: └── 20
# 2025-03-24 12:52:28,188:     ├── 30
# 2025-03-24 12:52:28,191:     └── 10
# ...
