# %%
from modulo_compressao.casamento_de_cadeia import * 
from modulo_arvores.utils import *
from objects.logger import Logger
import random
Logger.get_instance().activate()

# %%
# Texto e padrão para o teste
texto = "GACCCGACCGACTACCG"
padrao = "ACCG"

# Criar uma instância do BoyerMoore
bm = BoyerMoore(texto, padrao)

# Chamar o método de busca
matches = bm.buscar()

# Exibir os resultados encontrados
print(f"Matches encontrados nos índices: {matches}")
# Out:
# 2025-03-26 15:40:33,266: Texto: GACCCGACCGACTACCG
#
# 2025-03-26 15:40:33,267: Heurística de Ocorrência (Tabela de Deslocamento):
# 2025-03-26 15:40:33,267: 'A': 3
# 2025-03-26 15:40:33,268: 'C': 1
# 2025-03-26 15:40:33,268: 'G': 4
# 2025-03-26 15:40:33,269:
# 2025-03-26 15:40:33,269: Posição 0:
# 2025-03-26 15:40:33,269: GACCCGACCGACTACCG
# 2025-03-26 15:40:33,270: ACCG
# 2025-03-26 15:40:33,270: ✗ Não match em 3 ('C' ≠ 'G')
# 2025-03-26 15:40:33,270: → Deslocando 1 posições
#
# 2025-03-26 15:40:33,270: Posição 1:
# 2025-03-26 15:40:33,271: GACCCGACCGACTACCG
# 2025-03-26 15:40:33,271:  ACCG
# 2025-03-26 15:40:33,271: ✗ Não match em 4 ('C' ≠ 'G')
# 2025-03-26 15:40:33,272: → Deslocando 1 posições
#
# 2025-03-26 15:40:33,272: Posição 2:
# 2025-03-26 15:40:33,272: GACCCGACCGACTACCG
# 2025-03-26 15:40:33,273:   ACCG
# 2025-03-26 15:40:33,273: ✓ Match no índice 5: 'G'
# 2025-03-26 15:40:33,273: ✓ Match no índice 4: 'C'
# 2025-03-26 15:40:33,273: ✓ Match no índice 3: 'C'
# ...

# %%
# Texto e padrão para o teste
texto = "GACCCGACCGACTACCG"
padrao = "ACCG"

# Criar uma instância do BoyerMooreHorspool
bmh = BoyerMooreHorspool(texto, padrao)

# Chamar o método de busca
matches = bmh.buscar()

print(f"Matches encontrados nos índices: {matches}")
# Out:
# 2025-03-26 15:40:33,292: Texto: GACCCGACCGACTACCG
#
# 2025-03-26 15:40:33,293: Heurística de Ocorrência (Tabela de Deslocamento):
# 2025-03-26 15:40:33,293: 'A': 3
# 2025-03-26 15:40:33,294: 'C': 1
# 2025-03-26 15:40:33,294: 'G': 4
# 2025-03-26 15:40:33,295:
# 2025-03-26 15:40:33,295: Posição 0:
# 2025-03-26 15:40:33,295: GACCCGACCGACTACCG
# 2025-03-26 15:40:33,296: ACCG
# 2025-03-26 15:40:33,296: ✗ Não match em 3 ('C' ≠ 'G')
# 2025-03-26 15:40:33,296: → Deslocando 1 posições
#
# 2025-03-26 15:40:33,297: Posição 1:
# 2025-03-26 15:40:33,297: GACCCGACCGACTACCG
# 2025-03-26 15:40:33,297:  ACCG
# 2025-03-26 15:40:33,298: ✗ Não match em 4 ('C' ≠ 'G')
# 2025-03-26 15:40:33,298: → Deslocando 1 posições
#
# 2025-03-26 15:40:33,298: Posição 2:
# 2025-03-26 15:40:33,299: GACCCGACCGACTACCG
# 2025-03-26 15:40:33,299:   ACCG
# 2025-03-26 15:40:33,299: ✓ Match no índice 5: 'G'
# 2025-03-26 15:40:33,300: ✓ Match no índice 4: 'C'
# 2025-03-26 15:40:33,300: ✓ Match no índice 3: 'C'
# ...

# %%
# Texto e padrão para o teste
texto = "GACCCGACCGACTACCG"
padrao = "ACCG"

# Criar uma instância do BoyerMooreHorspool
bmhs = BoyerMooreHorspoolSmith(texto, padrao)

# Chamar o método de busca
matches = bmhs.buscar()

print(f"Matches encontrados nos índices: {matches}")
# Out:
# 2025-03-26 15:40:33,317: Texto: GACCCGACCGACTACCG
#
# 2025-03-26 15:40:33,317: Heurística de Ocorrência (Tabela de Deslocamento BMHS):
# 2025-03-26 15:40:33,317: 'A': 4
# 2025-03-26 15:40:33,318: 'C': 2
# 2025-03-26 15:40:33,318: 'G': 1
# 2025-03-26 15:40:33,319: *: 5  # Para caracteres não presentes no padrão
#
# 2025-03-26 15:40:33,319: Posição 0:
# 2025-03-26 15:40:33,319: GACCCGACCGACTACCG
# 2025-03-26 15:40:33,319: ACCG
# 2025-03-26 15:40:33,320: ✗ Não match em 3 ('C' ≠ 'G')
# 2025-03-26 15:40:33,320: → Deslocando 2 posições (baseado no próximo caractere do texto 'C')
#
# 2025-03-26 15:40:33,320: Posição 2:
# 2025-03-26 15:40:33,320: GACCCGACCGACTACCG
# 2025-03-26 15:40:33,321:   ACCG
# 2025-03-26 15:40:33,321: ✓ Match no índice 5: 'G'
# 2025-03-26 15:40:33,321: ✓ Match no índice 4: 'C'
# 2025-03-26 15:40:33,321: ✓ Match no índice 3: 'C'
# 2025-03-26 15:40:33,322: ✗ Não match em 2 ('C' ≠ 'A')
# ...

# %%
# Texto e padrão para o teste
texto = "ABABABABC"
padrao = "ABABC"

# Criar uma instância do ShiftAnd
shift_and = ShiftAnd(texto, padrao)

# Chamar o método de busca
matches = shift_and.buscar()

print(f"Matches encontrados nos índices: {matches}")
# Out:
# 2025-03-26 15:40:33,339: === PRÉ-PROCESSAMENTO ===
# 2025-03-26 15:40:33,339: Máscaras de caracteres:
# 2025-03-26 15:40:33,340: |    | 0  1  2  3  4 |
# 2025-03-26 15:40:33,340: |---|---|---|---|---|---|
# 2025-03-26 15:40:33,340: | M[A] | 1  0  1  0  0 |
# 2025-03-26 15:40:33,341: | M[B] | 0  1  0  1  0 |
# 2025-03-26 15:40:33,341: | M[C] | 0  0  0  0  1 |
# 2025-03-26 15:40:33,342:
# === EXECUÇÃO DETALHADA ===
# 2025-03-26 15:40:33,342:
# Passo 0: Processando 'A'
# 2025-03-26 15:40:33,342: R anterior:       0 0 0 0 0
# 2025-03-26 15:40:33,343: R << 1:           0 0 0 0 0
# 2025-03-26 15:40:33,343: (R << 1) | 1:     0 0 0 0 1
# 2025-03-26 15:40:33,343: Máscara 'A':      0 0 1 0 1
# 2025-03-26 15:40:33,344: Novo R:           0 0 0 0 1
# 2025-03-26 15:40:33,344: -----------------------
# 2025-03-26 15:40:33,344:
# Passo 1: Processando 'B'
# 2025-03-26 15:40:33,345: R anterior:       0 0 0 0 1
# 2025-03-26 15:40:33,345: R << 1:           0 0 0 1 0
# ...
