# %%
from lista_prioridades.arvore_heap import * 
from modulo_arvores.utils import *
from objects.logger import Logger
import random
Logger.get_instance().activate()

# %%
# Exemplo 1: Construindo o Heap Máximo com a lista de números fornecidos
heap_max = Heap(tipo="max")
numeros = [11, 30, 8, 10, 24, 22, 5, 12, 1, 20, 13, 23, 18, 3]

# Inserindo os números no heap
for numero in numeros:
    heap_max.inserir(numero)

# Exibindo o heap máximo após a inserção
print("Heap Máximo após a inserção dos números:")
print(heap_max.exibir_arvore())
# Out:
# 2025-03-24 15:00:07,116: Heap criado com sucesso.
# 2025-03-24 15:00:07,117: Inserido nó com chave 11.
# 2025-03-24 15:00:07,119: Árvore atual:
# └── 11
#
# 2025-03-24 15:00:07,120: Inserido nó com chave 30.
# 2025-03-24 15:00:07,122: Árvore atual:
# └── 30
#     └── 11
#
# 2025-03-24 15:00:07,123: Inserido nó com chave 8.
# 2025-03-24 15:00:07,127: Árvore atual:
# └── 30
#     ├── 11
#     └── 8
#
# 2025-03-24 15:00:07,128: Inserido nó com chave 10.
# 2025-03-24 15:00:07,129: Árvore atual:
# └── 30
#     ├── 11
#     │   └── 10
#     └── 8
#
# 2025-03-24 15:00:07,130: Inserido nó com chave 24.
# 2025-03-24 15:00:07,131: Árvore atual:
# └── 30
#     ├── 24
#     │   ├── 10
#     │   └── 11
#     └── 8
#
# 2025-03-24 15:00:07,132: Inserido nó com chave 22.
# 2025-03-24 15:00:07,137: Árvore atual:
# └── 30
#     ├── 24
#     │   ├── 10
#     │   └── 11
#     └── 22
#         └── 8
#
# 2025-03-24 15:00:07,139: Inserido nó com chave 5.
# 2025-03-24 15:00:07,141: Árvore atual:
# └── 30
# ...

# %%
# Exemplo 2: Alterando as prioridades
heap_max.alterar_prioridade(30, 4)  # Alterando a prioridade de 30 para 4
heap_max.alterar_prioridade(1, 31)  # Alterando a prioridade de 1 para 31
heap_max.alterar_prioridade(10, 29)  # Alterando a prioridade de 10 para 29
# Out:
# 2025-03-24 15:00:07,276: Prioridade alterada no nó com chave 30 para 4.
# 2025-03-24 15:00:07,281: Árvore atual:
# └── 24
#     ├── 20
#     │   ├── 12
#     │   │   ├── 10
#     │   │   └── 1
#     │   └── 13
#     │       ├── 11
#     │       └── 4
#     └── 23
#         ├── 22
#         │   ├── 8
#         │   └── 18
#         └── 5
#             └── 3
#
# 2025-03-24 15:00:07,285: Prioridade alterada no nó com chave 1 para 31.
# 2025-03-24 15:00:07,291: Árvore atual:
# └── 31
#     ├── 24
#     │   ├── 20
#     │   │   ├── 10
#     │   │   └── 12
#     │   └── 13
#     │       ├── 11
#     │       └── 4
#     └── 23
#         ├── 22
#         │   ├── 8
#         │   └── 18
#         └── 5
#             └── 3
#
# 2025-03-24 15:00:07,292: Prioridade alterada no nó com chave 10 para 29.
# 2025-03-24 15:00:07,295: Árvore atual:
# └── 31
#     ├── 29
#     │   ├── 24
#     │   │   ├── 20
#     │   │   └── 12
#     │   └── 13
#     │       ├── 11
#     │       └── 4
#     └── 23
# ...

# %%
# Exemplo 3: Removendo 3 elementos prioritários
print("Removendo 3 elementos prioritários:")
heap_max.remover()
heap_max.remover()
heap_max.remover()
# Out:
# 2025-03-24 15:00:07,363: Removido nó com chave 31.
# 2025-03-24 15:00:07,363: Árvore atual:
# └── 29
#     ├── 24
#     │   ├── 20
#     │   │   ├── 3
#     │   │   └── 12
#     │   └── 13
#     │       ├── 11
#     │       └── 4
#     └── 23
#         ├── 22
#         │   ├── 8
#         │   └── 18
#         └── 5
#
# 2025-03-24 15:00:07,364: Removido nó com chave 29.
# 2025-03-24 15:00:07,365: Árvore atual:
# └── 24
#     ├── 20
#     │   ├── 18
#     │   │   ├── 3
#     │   │   └── 12
#     │   └── 13
#     │       ├── 11
#     │       └── 4
#     └── 23
#         ├── 22
#         │   └── 8
#         └── 5
#
# 2025-03-24 15:00:07,365: Removido nó com chave 24.
# 2025-03-24 15:00:07,367: Árvore atual:
# └── 23
#     ├── 20
#     │   ├── 18
#     │   │   ├── 3
#     │   │   └── 12
#     │   └── 13
#     │       ├── 11
#     │       └── 4
#     └── 22
#         ├── 8
#         └── 5
# Removendo 3 elementos prioritários:
# ...
